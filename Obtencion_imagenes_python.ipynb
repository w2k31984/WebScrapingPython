# %% [markdown]
# # Obtener imagenes

# %%
#Peticion Http
import requests
#WebScrapping
from bs4 import BeautifulSoup

# %%
url='https://www.amazon.com/Kindle-eBooks/b?ie=UTF8&node=154606011'
page = requests.get(url)
page
# Out:
# <Response [200]>

# %%
head = {'User-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.77 Safari/537.36 Edg/91.0.864.41'}
page = requests.get(url, headers = head)
page
# Out:
# <Response [200]>

# %%
soap = BeautifulSoup(page.content)

# %%
soap.title.string
# Out:
# 'Amazon.com: Kindle eBooks: Kindle Store: Nonfiction, Literature & Fiction, Foreign Languages, Business & Money & More'

# %%
page.text
# Out:
# '<!doctype html><html lang="en-us" class="a-no-js" data-19ax5a9jf="dingo"><!-- sp:feature:head-start -->\n<head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>\n\n<script type=\'text/javascript\'>var ue_t0=ue_t0||+new Date();</script>\n<!-- sp:feature:cs-optimization -->\n<meta http-equiv=\'x-dns-prefetch-control\' content=\'on\'>\n<link rel="dns-prefetch" href="https://images-na.ssl-images-amazon.com">\n<link rel="dns-prefetch" href="https://m.media-amazon.com">\n<link rel="dns-prefetch" href="https://completion.amazon.com">\n<script type=\'text/javascript\'>\nwindow.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;\nif (window.ue_ihb === 1) {\n\nvar ue_csm = window,\n    ue_hob = +new Date();\n(function(d){var e=d.ue=d.ue||{},f=Date.now||function(){return+new Date};e.d=function(b){return f()-(b?0:d.ue_t0)};e.stub=function(b,a){if(!b[a]){var c=[];b[a]=function(){c.push([c.slice.call(arguments),e.d(),d.ue_id])};b[a].replay=function(b){for(var a;a=c.
# ...

# %% [markdown]
# # Practica de obtencion de pagina de sitio web

# %%
url='https://www.amazon.com/b/ref=dp_bc_aui_C_4?ie=UTF8&node=3741111'
page = requests.get(url)
page
# Out:
# <Response [503]>

# %%
head={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.113 Safari/537.36'}
page = requests.get(url, headers=head)
print(page)
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content)
soup.title.string
#page.content #entrega la informacion sin procesar
# Out:
# 'Amazon.com : Replacement Water Filters'

# %%
page.text #entrega la informacion en modo texto
# Out:
# '<!doctype html><html lang="en-us" class="a-no-js" data-19ax5a9jf="dingo"><!-- sp:feature:head-start -->\n<head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>\n\n<script type=\'text/javascript\'>var ue_t0=ue_t0||+new Date();</script>\n<!-- sp:feature:cs-optimization -->\n<meta http-equiv=\'x-dns-prefetch-control\' content=\'on\'>\n<link rel="dns-prefetch" href="https://images-na.ssl-images-amazon.com">\n<link rel="dns-prefetch" href="https://m.media-amazon.com">\n<link rel="dns-prefetch" href="https://completion.amazon.com">\n<script type=\'text/javascript\'>\nwindow.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;\nif (window.ue_ihb === 1) {\n\nvar ue_csm = window,\n    ue_hob = +new Date();\n(function(d){var e=d.ue=d.ue||{},f=Date.now||function(){return+new Date};e.d=function(b){return f()-(b?0:d.ue_t0)};e.stub=function(b,a){if(!b[a]){var c=[];b[a]=function(){c.push([c.slice.call(arguments),e.d(),d.ue_id])};b[a].replay=function(b){for(var a;a=c.
# ...

# %% [markdown]
# # Obtener imagenes desde Amazon

# %%
images = []
sufix = 'https://m.media-amazon.com'
imgs = soup.find("div",{"class":"s-main-slot s-result-list s-search-results sg-row"}).findAll("img")
#img = soup.find("div",{"class":"a-section aok-relative s-image-square-aspect"}).find("img")
for aux in imgs:
    if (aux["src"].find(sufix)!=-1):
        images.append(aux["src"])
#Muestra los nombres de las imagenes
#print(images)
#print(images.length)
len(images)
# Out:
# 39

# %%
#Cuantas imagenes nos trajo sin repetirse.
images = list(dict.fromkeys(images))
len(images)
# Out:
# 37

# %% [markdown]
# # Descargar imagenes del sitio de Amazon.

# %%
#Los archivos de imagenes los descargara directo a la carpeta donde esta el proyecto.
i=0
for url in images:
    imagen = requests.get(url).content
    with open(str(i)+".jpg", 'wb') as handler:
        handler.write(imagen)
    i+=1
